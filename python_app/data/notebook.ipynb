# %%
import pandas as pd
#import numpy as np
#Define the file paths
csv_file_customers = r'C:\Users\Admin\Desktop\Module5\python_app\data\03_Library SystemCustomers.csv'
csv_file_books = r'C:\Users\Admin\Desktop\Module5\python_app\data\03_Library Systembook.csv'

#Load the file path into a data frame
df_books = pd.read_csv(csv_file_books)
df_customers = pd.read_csv(csv_file_customers)

#print(df_books.head())
#print(df_cusomers.head())

# %%
#Clean customers file:
#1 Remove duplicates:
df_customers.drop_duplicates()

#Drop NA rows
df_customers_cleaned = df_customers.dropna()

#Ensure consistency of data types
df_customers_cleaned['Customer ID'] = df_customers_cleaned['Customer ID'].astype('int64')
df_customers_cleaned['Customer Name'] = df_customers_cleaned['Customer Name'].astype('string')

print(df_customers_cleaned)
# Out:
#    Customer ID     Customer Name
# 0            1          Jane Doe
# 1            2        John Smith
# 2            3        Dan Reeves
# 4            5    William Holden
# 5            6     Jaztyn Forest
# 6            7     Jackie Irving
# 7            8  Matthew Stirling
# 8            9         Emory Ted
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\1714332129.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_customers_cleaned['Customer ID'] = df_customers_cleaned['Customer ID'].astype('int64')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\1714332129.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_customers_cleaned['Customer Name'] = df_customers_cleaned['Customer Name'].astype('string')

# %%
#Clean books file:
#1 Remove duplicates:
df_books.drop_duplicates()

df_books_nan = df_books[df_books.isna().any(axis=1)]

#Drop NA rows
df_books_cleaned = df_books.dropna()

#Ensure consistency of data types
df_books_cleaned['Id'] = df_books_cleaned['Id'].astype('int64')
df_books_cleaned['Books'] = df_books_cleaned['Books'].astype('string')

df_books_cleaned['Book Returned'] = df_books_cleaned['Book Returned'].str.strip()
df_books_cleaned['Book checkout'] = df_books_cleaned['Book checkout'].str.replace('"','', regex = False)
df_books_cleaned['Book checkout'] = pd.to_datetime(df_books_cleaned['Book checkout'],errors='coerce')
df_books_cleaned['Book checkout'] = df_books_cleaned['Book checkout'].fillna(pd.Timestamp('1900-01-01'))

df_books_cleaned['Book Returned'] = df_books_cleaned['Book Returned'].str.strip()
df_books_cleaned['Book Returned'] = pd.to_datetime(df_books_cleaned['Book Returned'],errors='coerce')

df_books_cleaned['Days allowed to borrow'] = df_books_cleaned['Days allowed to borrow'].astype('string')

df_books_cleaned['Customer ID'] = df_books_cleaned['Customer ID'].astype('int64')

print(df_books_cleaned)
#print(df_books_nan)
# Out:
#     Id                                     Books Book checkout Book Returned  \
# 0    1                       Catcher in the Rye     2023-02-20    2023-02-25
# 1    2          Lord of the rings the two towers    2023-03-24    2023-03-21
# 2    3  Lord of the rings the return of the kind    2023-03-29    2023-03-25
# 3    4                                The hobbit    2023-04-02    2023-03-25
# 4    5                                     Dune     2023-04-02    2023-03-25
# 5    6                              Little Women    2023-04-02    2023-05-01
# 6    7                                        IT    2063-04-10    2023-04-03
# 7    8                                   Misery     2023-04-15    2023-04-03
# 8    9                                  Catch 22    2023-04-15    2023-04-16
# 9   10                              Animal Farm     2023-04-20    2023-04-24
# 10  11                                      1984    2023-04-23    2023-04-27
# 11  12                              Little Women    2023-04-02    2023-05-01
# 12  13                              East of Eden    2023-04-30    2023-05-05
# 13  14                   America Is in the Heart    2023-05-01    2023-05-07
# 14  15                         Wuthering Heights    2023-05-01    2023-05-10
# 15  16                                Dark Tales    2023-05-15    2023-06-01
# 16  17                        The Bloody Chamber    1900-01-01    2023-06-04
# 17  18                            Les Miserables    2023-06-03    2023-06-07
# 18  19                                   Dracula    2023-06-10    2023-07-10
# 19  20                              Frankenstein    2023-06-01    2023-06-20
#
#    Days allowed to borrow  Customer ID
# 0                 2 weeks            1
# 1                 2 weeks            2
# 2                 2 weeks            3
# 3                 2 weeks            4
# 4                 2 weeks            5
# 5                 2 weeks            1
# 6                 2 weeks            6
# 7                 2 weeks            7
# 8                 2 weeks            7
# 9                 2 weeks            2
# 10                2 weeks            8
# 11                2 weeks            1
# 12                2 weeks            2
# 13                2 weeks            3
# 14                2 weeks            9
# 15                2 weeks            2
# 16                2 weeks            3
# 17                2 weeks            5
# 18                2 weeks           10
# 19                2 weeks            2
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Id'] = df_books_cleaned['Id'].astype('int64')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Books'] = df_books_cleaned['Books'].astype('string')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book Returned'] = df_books_cleaned['Book Returned'].str.strip()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book checkout'] = df_books_cleaned['Book checkout'].str.replace('"','', regex = False)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:16: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_books_cleaned['Book checkout'] = pd.to_datetime(df_books_cleaned['Book checkout'],errors='coerce')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book checkout'] = pd.to_datetime(df_books_cleaned['Book checkout'],errors='coerce')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book checkout'] = df_books_cleaned['Book checkout'].fillna(pd.Timestamp('1900-01-01'))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book Returned'] = df_books_cleaned['Book Returned'].str.strip()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:20: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_books_cleaned['Book Returned'] = pd.to_datetime(df_books_cleaned['Book Returned'],errors='coerce')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Book Returned'] = pd.to_datetime(df_books_cleaned['Book Returned'],errors='coerce')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Days allowed to borrow'] = df_books_cleaned['Days allowed to borrow'].astype('string')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\610179705.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['Customer ID'] = df_books_cleaned['Customer ID'].astype('int64')

# %%
#Add calculated columns:

df_books_cleaned['days between checkout and return'] = (df_books_cleaned['Book Returned'] - df_books_cleaned['Book checkout']).dt.days
df_books_cleaned['days between checkout and return'] = df_books_cleaned['days between checkout and return'].astype('Int64')

#print(df_books_cleaned)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\1195797237.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['days between checkout and return'] = (df_books_cleaned['Book Returned'] - df_books_cleaned['Book checkout']).dt.days
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14556\1195797237.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_cleaned['days between checkout and return'] = df_books_cleaned['days between checkout and return'].astype('Int64')

# %%
import pyodbc

#Connect to SQL Server
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=STUDENT06;'
    'DATABASE=LibraryBronceDB;'
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()

#Convert NaN into nulls:
#df_customers_cleaned = df_customers_cleaned.where(pd.notnull(df_customers_cleaned), None)
#df_books_cleaned = df_books_cleaned.where(pd.notnull(df_books_cleaned), None)

# Insert Dataframe Customers into SQL Server:
cursor.execute("TRUNCATE TABLE Customers_extract")
for index, row in df_customers_cleaned.iterrows():
     cursor.execute("INSERT INTO Customers_extract ([Customer ID],[Customer Name]) values(?,?)", row['Customer ID'], row['Customer Name'])


# Insert Dataframe Customers into SQL Server:
cursor.execute("TRUNCATE TABLE Books_extract")
for index, row in df_books_cleaned.iterrows():
     cursor.execute("INSERT INTO Books_extract ([Id],[Books],[Book checkout], [Book Returned], [Days allowed to borrow], [Customer ID], [days between checkout and return]) values(?,?,?,?,?,?,?)", row['Id'], row['Books'],row['Book checkout'], row['Book Returned'], row['Days allowed to borrow'], row['Customer ID'], row['days between checkout and return'])
conn.commit()
cursor.close()
